# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 가져와서 압축 풀기
# !cp /content/drive/MyDrive/data/high-resolution-viton-zalando-dataset.zip ./

# %%
# !mkdir viton-hd

# %%
# 가져와서 압축 풀기
# !cp /content/drive/MyDrive/data/train_pairs_sample.txt .

# %% [markdown]
# 학습 파이프라인 이동하기

# %%
# !cp /content/VTON-project/pipeline_minimal.py /content/VTON-project/CatVTON/model/
# !cp /content/VTON-project/pipeline_one_timestep.py /content/VTON-project/CatVTON/model/
# !cp /content/VTON-project/pipeline_minimal.py /content/VTON-project/CatVTON/model/pipeline_minimal.py

# %%
# !unzip -q /content/high-resolution-viton-zalando-dataset.zip

# %%
ls
# Out:
# drive/                                     test/           train_pairs_sample.txt
# high-resolution-viton-zalando-dataset.zip  test_pairs.txt  train_pairs.txt
# sample_data/                               train/          viton-hd/

# %%
# 구글 드라이브 연결후 data 폴더에 다운
# cd /content/drive/MyDrive/data

# %%
#!/bin/bash
# !kaggle datasets download marquis03/high-resolution-viton-zalando-dataset

# %%
# ls

# %%
# cd /content

# %%
# !unzip -q -o high-resolution-viton-zalando-dataset.zip

# %%
# !git clone https://github.com/WheelWear/VTON-project.git
# Out:
# Cloning into 'VTON-project'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 266 (delta 17), reused 20 (delta 10), pack-reused 238 (from 1)
# Receiving objects: 100% (266/266), 135.98 MiB | 22.97 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
ls
# Out:
# drive/                                     test/           train_pairs_sample.txt  VTON-project/
# high-resolution-viton-zalando-dataset.zip  test_pairs.txt  train_pairs.txt
# sample_data/                               train/          viton-hd/

# %%
cd /content/VTON-project/
# Out:
# /content/VTON-project

# %%
# !git clone https://github.com/Zheng-Chong/CatVTON.git
# Out:
# Cloning into 'CatVTON'...
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 1342 (delta 48), reused 39 (delta 30), pack-reused 1273 (from 2)
# Receiving objects: 100% (1342/1342), 16.74 MiB | 18.30 MiB/s, done.
# Resolving deltas: 100% (445/445), done.

# %%
# !unzip -q -o dataset_v1.2.zip -d dataset/

# %%
cp pipeline.py CatVTON/model
# Out:
# cp: cannot stat 'pipeline.py': No such file or directory

# %%
# !ls CatVTON/model
# Out:
# attn_processor.py  cloth_masker.py  DensePose  flux  pipeline.py  SCHP	utils.py

# %%
# cat CatVTON/model/pipeline.py

# %%
pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-kbi8028r
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-kbi8028r
#   Resolved https://github.com/huggingface/diffusers.git to commit 924f880d4da3af3d376ed8d834e613192071fee4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# ...

# %%
pwd
# Out:
# '/content/VTON-project'

# %%
import wandb

# W&B 로그인
wandb_api = "7df92b5f77c812550e3f38029dc2c0a7bb2b7caa"
wandb.login(key=wandb_api)

print("W&B 로그인 완료!")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: coldbrew (x_team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W&B 로그인 완료!

# %%
# !run_hyper_train.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# loss : tensor(25.5962, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.48it/s]
# loss : tensor(26.0367, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.47it/s]
# loss : tensor(26.0365, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.47it/s]
# loss : tensor(26.0780, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.48it/s]
# loss : tensor(25.7609, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.47it/s]
# loss : tensor(26.4512, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.48it/s]
# loss : tensor(26.1037, device='cuda:0', grad_fn=<MseLossBackward0>)
#
#   0% 0/1 [00:00<?, ?it/s]
# ...
